# %% [markdown]
# # 01_06 — Primeiros comandos Python
#
# > **Material de familiarização com o JupyterLab do SimServ.**
# > Estes notebooks foram pensados para ficar em uma pasta de somente leitura, por exemplo `/sobre_ambientes_simserv`.
# > Para editar, testar livremente ou salvar resultados, faça uma cópia para sua área de trabalho, como `/home/jovyan/work` ou `/home/jovyan/laboratorio`.

# %% [markdown]
# ## Objetivo
#
# Testar comandos Python muito simples no JupyterLab.

# %%
print("Primeiro teste no SimServ")

# %%
2 + 3

# %%
10 * 5

# %% [markdown]
# ## Variáveis
#
# Uma variável guarda um valor para ser usado depois.

# %%
idade = 20
idade_no_ano_que_vem = idade + 1
print(idade_no_ano_que_vem)

# %%
nome = "Maria"
print("Olá,", nome)

# %% [markdown]
# ## Exercício
#
# Altere os valores de `idade` e `nome` e execute novamente as células.
