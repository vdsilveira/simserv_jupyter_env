# %% [markdown]
# # 01_01 — Primeiro contato com o JupyterLab
#
# > **Material de familiarização com o JupyterLab do SimServ.**
# > Estes notebooks foram pensados para ficar em uma pasta de somente leitura, por exemplo `/sobre_ambientes_simserv`.
# > Para editar, testar livremente ou salvar resultados, faça uma cópia para sua área de trabalho, como `/home/jovyan/work` ou `/home/jovyan/laboratorio`.

# %% [markdown]
# ## Objetivo
#
# Neste notebook você vai executar suas primeiras células.
# Clique em uma célula de código e pressione **Shift + Enter** para executar.

# %%
print("Olá! Estou usando o JupyterLab no SimServ.")
# Out:
# Olá! Estou usando o JupyterLab no SimServ.

# %% [markdown]
# ## Células de texto e células de código
#
# Esta célula é uma célula **Markdown**. Ela serve para explicações.
#
# A próxima célula é uma célula **Code**. Ela será executada pelo Python.

# %%
nome = "Aluno"
print(f"Bem-vindo ao SimServ, {nome}!")
# Out:
# Bem-vindo ao SimServ, Aluno!

# %% [markdown]
# ## Executar em ordem
#
# Em notebooks, uma célula pode depender de outra. Por isso, como regra inicial, execute de cima para baixo.

# %%
a = 2
b = 3
resultado = a + b
print("Resultado:", resultado)
# Out:
# Resultado: 5

# %% [markdown]
# ## Pequeno exercício
#
# Altere o valor da variável `nome` na célula acima, salve uma cópia do notebook na sua área de trabalho e execute novamente.
